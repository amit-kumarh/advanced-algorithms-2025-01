# %% [markdown]
# # Heuristics Lab
# The goal of this lab is to gain experience using heuristics in tandem with other algorithms.
#
# For the purposes of this assignment, you will be implementing a solver for the "2048" game (whose implementation will already be given to you). Before continuing, the following cell contains any dependencies you may need for this assignment:

# %%
import matplotlib.pyplot as plt

from game import *

# %% [markdown]
# You should also look at `game.py` to understand how the in-line version has been implemented.

# %% [markdown]
# ## Background Info
#
# 2048 is a single-player sliding block puzzle game played on a 4x4 grid where tiles containing even numbers can be moved around and merged to create larger numbers. If this does not ring a bell, it is highly recommended that you play the game at some point (enjoy the cupcake version [here](https://0x0800.github.io/2048-CUPCAKES/)).
#
# While the implementation has been given, ensure that you understand what a tile, a turn, a legal move, and when the game ends is.
#
# This particular implementation/walk through focuses on utilization of heuristic functions themselves (or strategies that are simple enough that a human player could follow them) & only looks ahead by 1 move (as opposed to adding this heuristic into another algorithm like nimimax or expectimax - which would yield better results)
#
# Questions:
# 1. What is a potential representation of the solution space?
# 2. How can you evaluate the results of a single move?
# 3. How might you select and combine heuristics?
# 4. How can you evaluate the results of an entire game?

# %% [markdown]
# ## A. Assessing the Problem
#
# What is a potential representation of the solution space?
#
# Every potential 2048 position.
#
# Play a SINGLE round of 2048 (you can do this on the website with the nice UI instead of the text version). What score did you get?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## B. Evaluating a Single Move
#
# Before implementing specific heuristics, a general implementation procedure must be formed.
#
# Use the following pseudocode to write a function to evaluate a game _G_ in its current state:
#
# **Input:** _G_ - a game, _M_ - a set of moves \
# **Output:** The best moves according to the specific evaluator
#
# **procedure** EvaluateGame(_G_, _M_)\
# &emsp;_bestScore_ ← −1\
# &emsp;_bestMoves_ ← ∅\
# &emsp;**for all** _move_ ∈ _M_ **do**\
# &emsp;&emsp;_G'_ ← _G_\
# &emsp;&emsp;apply _move_ to _G'_\
# &emsp;&emsp;_curScore_ ← the score given by the evaluator’s specific criteria\
# &emsp;&emsp;**if** _curScore_ > _bestScore_ **then**\
# &emsp;&emsp;&emsp;_bestScore_ ← _curScore_\
# &emsp;&emsp;&emsp;_bestMoves_ ← {_move_}\
# &emsp;&emsp;**else if** _curScore_ = _bestScore_ **then**\
# &emsp;&emsp;&emsp;_bestMoves_ ← _bestMoves_ ∪ {_move_}\
# &emsp;&emsp;**end if**\
# &emsp;**end for**\
# &emsp;return _bestMoves_\
# **end procedure**
#
# For now, use the overall game score as the evaluation criteria. Remember to consider how the game/board is referenced when running each move.

# %%
def evaluate_game(game, moves):
    best_score = -1
    best_moves = []
    for m in MOVES:
        game2 = game
        game2.move(m)
        score = game2.score
        if score > best_score:
            best_score = score
            best_moves.append(m)
        elif score == best_score:
            best_moves.append(m)
    return best_moves

# %% [markdown]
# ## C. Selecting Heuristics
#
# ### Refactoring Evaluation
#
# At this point in time, the solver uses a 'greedy' heuristic of purely selecting tiles based on the highest immediate increase to score.  Before we try other heuristics, let's refactor the `evaluate_move()` function to take in a heuristic function instead of hardcoding the evaluator's criteria.
#
# After updating the function, it can be tested with the given `game_score()` heuristic function.

# %%
def game_score(game):
    return game.score

def evaluate_game (game, moves, heuristic): 
    best_score = -1
    best_moves = []
    for m in moves:
        game2 = game
        if game2.play_turn(m):
            score = heuristic(game2)
            if score >= best_score:
                best_score = score
                best_moves.append(m)
    return best_moves

# %% [markdown]
# We should also define a random move selection function as a groud zero/baseline point of comparison.

# %%
import random

def random_move(moves):
    return random.choice(moves)

# %% [markdown]
# ### Various Heuristics
#
# There are multiple heuristics that can be used to solve a 2048 game:
# - Greedy - approximates in-game score after each move & return the one with the highest result
# - Monotincity - values are either non-increasing or non-decreasing along all rows and non-increasing or non-decreasing along all columns
# - Empty - prioritizes moves that increases the # of empty tiles on the board
# - Smoothness - keeps tiles of similar value close to each other
# - Weight matrix - a grid w higher weighting tiles on one part of the grid (resulting in higher utility & the algorithm shifting tiles/converging them on one corner of weights)
#
# Pick two heuristics (other than greedy - which you already did) & write functions calculating those. You may choose another heuristic that is not on this list if you would prefer that.

# %%
# Replace with your code

def empty(game):
    return len([c for row in game.board for c in row if c == 0])

def monotincity(game):
    count = 0
    for row in game.board:
        if all(sorted(row) == row) or all(sorted(row, reverse=True) == row):
            count += 1

    for col in game.board.T:
        if all(sorted(col) == col) or all(sorted(col, reverse=True) == col):
            count += 1
    return count

# %% [markdown]
# ## D. Evaluating a Game
#
# ### Making the Solver
#
# Now that value has successfully been equated to the outcome of a single move, this needs to be done on the entire game.
#
# To start, your solver should take in a game and a heuristic to abide by.
#
# Most heuristic evaluators are non-terminal, meaning they will return more than one possible move of equal value. In order to combat this, a terminal evaluator must be included in the overall game solver to ensure only one move is selected. This can be done by randomly selecting from the list of "best moves" provided by the heuristic.

# %%
def run_solver(game, heuristic):
    while True:
        if not game.has_valid_moves():
            print("Final Score: ", game.score)
            break
        best_moves = evaluate_game(game, ['w', 'a', 's', 'd'], heuristic)
        if not game.play_turn(m := random_move(best_moves)):
            print("Invalid move; try again.")
    game.display()

# %% [markdown]
# Run the following cell to test your solver on just the `game_score` heuristic:

# %%
g = Board()
run_solver(g, game_score)
# Out:
# Final Score:  2384
# Score: 2384
# [[  8   2   8   2]
#  [  2   4  64   4]
#  [ 32   8  32   8]
#  [  8 256   4   2]]

# %% [markdown]
# Try the full game solver on some of your other heuristics. Note that sometimes they will flatline or get stuck in a pattern of moves that do not appear to converge in a termination point.

# %%
g = Board()
run_solver(g, empty)

g = Board()
run_solver(g, monotincity)
# Out:
# Final Score:  1696
# Score: 1696
# [[  4  64   4   2]
#  [  2   4  64  16]
#  [ 32 128  32   4]
#  [  8   4   2   8]]
# Final Score:  3212
# Score: 3212
# [[  8 128   8   2]
#  [  4  32 256   8]
#  [ 32  16  64  16]
#  [  2   4   8   4]]

# %% [markdown]
# #### Resolving Flatlining
#
# One way to resolve flatlining is to to update the solver to count for a certain number of repeating moves and reintroduce a random selection.

# %%
def run_solver(game, heuristic): 
    threshold = 50 # Replace with your code (this can be a hardcoded value)
    previous_move = None
    repeat_count = 0

    while True:
        if not game.has_valid_moves():
            print("Final Score: ", game.score)
            break
        best_moves = evaluate_game(game, ['w', 'a', 's', 'd'], heuristic)
        if not game.play_turn(m := random_move(best_moves)):
            print("Invalid move; try again.")
        
        if m == previous_move:
            repeat_count += 1
        else:
            repeat_count = 0
            previous_move = m
        
        if repeat_count == 50:
            break
        
    game.display() 
    return game.score

# %% [markdown]
# #### Combining Heuristics
#
# A simple way to incorporate multiple heuristics is to create a `combined_heuristic()` function that assigns weights to various heuristics. These weights can also help offset any discrepancies in the scale of resulting "scores".
#
# The combined score should be calculated by multiplying the weight of an individual heuristic's score with its score.

# %%
def combined_heuristic(game):
    h1 = empty(game)
    h2 = monotincity(game)    

    # Combine heuristics
    combined_score = 0.5 * h1 + 0.5 * h2

    return combined_score

g = Board()
run_solver(g, combined_heuristic)
# Out:
# Final Score:  3128
# Score: 3128
# [[  2   4   8   2]
#  [ 32 256 128   4]
#  [  4  16  64   2]
#  [  2   4  32   8]]

# %% [markdown]
# ### Plotting Results
#
# Run 100 cycles of each of your heuristics & plot your results. You should have at least 3 lines (score, your heuristic #1, your heuristic #2, and potentially a completely random implementation)

# %%
res = [[], [], []]
for _ in range(100):
    gs = [Board(), Board(), Board()]

    for i, h in enumerate([game_score, empty, monotincity]):
        res[i].append(run_solver(gs[i], h))
# Out:
# Final Score:  4984
# Score: 4984
# [[  2   4   2   4]
#  [  4 128   4 512]
#  [  8  32  16   8]
#  [  2   4   8   2]]
# Final Score:  1412
# Score: 1412
# [[  2   4  32   4]
#  [ 64   8   4 128]
#  [  8  32   2   8]
#  [  4  16   8   2]]
# Final Score:  2792
# Score: 2792
# [[  2   8  16   2]
#  [ 32   2 128   8]
#  [  4   8 256  16]
#  [ 16   4   8   4]]
# Final Score:  1152
# Score: 1152
# [[  4  16   4   2]
#  [  2  32   2  32]
#  [  8  16 128   2]
#  [  4   8   2   8]]
# Final Score:  2864
# Score: 2864
# [[  4   8   4   2]
#  [  8  16  32   4]
#  [  2  32 128  16]
#  [  4 256   4   2]]
# Final Score:  1384
# Score: 1384
# [[  8   2  16   2]
#  [  2  32   8   4]
#  [ 16  64  16 128]
#  [  2   8   2   8]]
# Final Score:  576
# Score: 576
# [[ 4  2  8  2]
#  [ 2 16 64 16]
#  [ 4  2  8  4]
#  [ 2  8 32  2]]
# Final Score:  2300
# Score: 2300
# [[  2  32   2   4]
#  [  8 256   4   2]
#  [ 16   4  64   8]
#  [  4  16   4   2]]
# Final Score:  2444
# Score: 2444
# [[  4  16   8   2]
#  [ 32   8 256   4]
#  [  4  16  64  32]
#  [  2   8   2   4]]
# Final Score:  2408
# Score: 2408
# [[  4  16   8   2]
#  [  2   8 256   8]
#  [ 32  64  32   2]
#  [  2   4   2   4]]
# Final Score:  868
# Score: 868
# [[ 2  8 16  4]
#  [ 8 32 64  2]
#  [ 4 64 16  4]
#  [ 2  8  4  2]]
# Final Score:  1356
# Score: 1356
# [[  2  64   4   2]
#  [  8   2  16  32]
#  [  4  16 128  16]
#  [  2   4   2   4]]
# Final Score:  1400
# Score: 1400
# [[  8  32   4   2]
#  [  4   2  16   8]
#  [  2   4 128  32]
#  [ 64   8   4   2]]
# Final Score:  560
# Score: 560
# [[ 2  4  8  2]
#  [ 8 32 16  4]
#  [ 2  8  4  8]
#  [ 4  2 64  2]]
# Final Score:  676
# Score: 676
# [[ 4  2  4  2]
#  [16  8  2 32]
#  [ 4 64 16  8]
#  [ 2 32  4  2]]
# Final Score:  1420
# Score: 1420
# [[  2   4  32   2]
#  [  4  64   8  16]
#  [  2  32 128   2]
#  [  8  16   8   4]]
# Final Score:  2080
# Score: 2080
# [[  8  16   8   2]
#  [  4   8  32  16]
#  [  2   4  16   8]
#  [  4 256   4   2]]
# Final Score:  1308
# Score: 1308
# [[  4   2  16   4]
#  [  2  16  64   2]
#  [128   4  32   8]
#  [  8   2   8   2]]
# Final Score:  780
# Score: 780
# [[ 8  2 16  8]
#  [ 2 64  4  2]
#  [64  8 16  4]
#  [ 2  4  8  2]]
# Final Score:  688
# Score: 688
# [[ 4  2 64  4]
#  [ 2 16 32  8]
#  [ 8  4  2  4]
#  [ 2 32 16  2]]
# Final Score:  968
# Score: 968
# [[ 2  4 16  4]
#  [32 64  8 64]
#  [ 8  4 32  4]
#  [ 4  8  4  2]]
# Final Score:  1596
# Score: 1596
# [[  2  32   4   8]
#  [  8  64  16   4]
#  [ 32  16 128  16]
#  [  2  32   4   2]]
# Final Score:  4312
# Score: 4312
# [[  2   4  16   4]
#  [ 32  16   4  16]
#  [  4 512  16   8]
#  [  2   4   2   4]]
# Final Score:  2812
# Score: 2812
# [[ 16   4  32   4]
#  [  4   2 128   2]
#  [256   4   2   8]
#  [ 32   2   4   2]]
# Final Score:  2352
# Score: 2352
# [[  2  32   2   4]
#  [  8   4  16  64]
#  [  2  16 256  16]
#  [  4   2   4   2]]
# Final Score:  3104
# Score: 3104
# [[  2   4  32   4]
#  [128  64   4   2]
#  [  4   8  16  32]
#  [  2 256   4   2]]
# Final Score:  1416
# Score: 1416
# [[  2   4  16   2]
#  [ 32  64 128   8]
#  [ 16  32   8   4]
#  [  4   8   4   2]]
# Final Score:  2980
# Score: 2980
# [[  2 128   2   4]
#  [  4  32   8   2]
#  [ 16   4  64   8]
#  [  4 256   4   2]]
# Final Score:  1080
# Score: 1080
# [[  4   2  32   2]
#  [  2   8   2   8]
#  [  4  16 128   2]
#  [  2  32   8   4]]
# Final Score:  2392
# Score: 2392
# [[  2   4  32   2]
#  [  8 256   8   4]
#  [  2  32  64   2]
#  [  8   2   8   4]]
# Final Score:  900
# Score: 900
# [[ 2 16  4  2]
#  [ 8  4 64  4]
#  [ 4 64  4 16]
#  [16  8 32  2]]
# Final Score:  708
# Score: 708
# [[ 2  4  8  2]
#  [ 4  8 32 16]
#  [32 64 16  8]
#  [ 2  4  8  4]]
# Final Score:  664
# Score: 664
# [[ 4 16  4  2]
#  [ 8  2 16  4]
#  [ 4 32 64 16]
#  [ 2 16  8  4]]
# Final Score:  2692
# Score: 2692
# [[  2   8  32   8]
#  [ 64  16   8   2]
#  [  2   4 256  64]
#  [  4  32   4   2]]
# Final Score:  1580
# Score: 1580
# [[  2   4  32   2]
#  [  4   8  64   4]
#  [128   4  16   2]
#  [  4   8  64   8]]
# Final Score:  2132
# Score: 2132
# [[  2   4   8 128]
#  [  8  32  64   2]
#  [  4  16  32   8]
#  [  2 128   8   2]]
# Final Score:  1664
# Score: 1664
# [[  4   2  16   2]
#  [ 16  64  32   4]
#  [  4 128  64   8]
#  [  2   4  16   2]]
# Final Score:  2952
# Score: 2952
# [[  2   4  16   2]
#  [  8 256  32  16]
#  [ 16  32 128   4]
#  [  2  16   8   2]]
# Final Score:  2504
# Score: 2504
# [[  8  32  16   2]
#  [  2  16 256   4]
#  [  8  32  64  16]
#  [  4   8   4   2]]
# Final Score:  2440
# Score: 2440
# [[  2  64  16   4]
#  [  8  32   8   2]
#  [  2 256   2  32]
#  [  8  16   8   2]]
# Final Score:  676
# Score: 676
# [[ 2  4  8 32]
#  [16  8  2  8]
#  [ 8 64  4  2]
#  [ 2  4  8 32]]
# Final Score:  1168
# Score: 1168
# [[ 4 16  2  4]
#  [32 64 32 16]
#  [ 4 16 64  8]
#  [ 8 32  4  2]]
# Final Score:  1320
# Score: 1320
# [[  2   4  16   4]
#  [  4   2  64   2]
#  [ 32   8 128   8]
#  [  2   4  16   4]]
# Final Score:  2396
# Score: 2396
# [[  2   4   8   2]
#  [  8   2  64   4]
#  [  2  32 256  32]
#  [ 16   8   4   2]]
# Final Score:  2336
# Score: 2336
# [[  4  16   4   2]
#  [ 64   8  16   8]
#  [  4 256  32   2]
#  [  2   8   2   4]]
# Final Score:  1288
# Score: 1288
# [[  2   4   2   8]
#  [  8 128   4  32]
#  [  4  64   8   2]
#  [  2   4  16   4]]
# Final Score:  2592
# Score: 2592
# [[  4   8   4   2]
#  [  8  16  64   8]
#  [  2  64 256   2]
#  [  8   4  32   4]]
# Final Score:  3072
# Score: 3072
# [[  4   8   2   4]
#  [  8 128  16  32]
#  [  4  64 256   4]
#  [  8  16   8   2]]
# Final Score:  2424
# Score: 2424
# [[  4  64 256   2]
#  [  2  32   8   4]
#  [  8   4  32  16]
#  [  2  16   2   4]]
# Final Score:  1164
# Score: 1164
# [[ 16  32   2   4]
#  [  8   4   8   2]
#  [ 16 128  32   8]
#  [  2   4  16   2]]
# Final Score:  1352
# Score: 1352
# [[  2   4  64   8]
#  [ 16   2   8  16]
#  [  2   4  32   8]
#  [  4  16 128   2]]
# Final Score:  2060
# Score: 2060
# [[  2  16   4   2]
#  [128   8   2   8]
#  [  4  64  16   2]
#  [ 32   4 128   4]]
# Final Score:  1456
# Score: 1456
# [[  2   4  16   2]
#  [  4   8  32   4]
#  [128  64  16  32]
#  [  2   8   4   2]]
# Final Score:  1444
# Score: 1444
# [[  4   8   2   4]
#  [ 16   4  16  32]
#  [  4  32 128   8]
#  [  2  64   8   2]]
# Final Score:  3332
# Score: 3332
# [[  2   4   2   8]
#  [ 16 256 128  16]
#  [  4  32  64   2]
#  [  2  64   2   8]]
# Final Score:  952
# Score: 952
# [[ 2 16  4  2]
#  [64  4 64  4]
#  [ 4 32  4 32]
#  [ 2  4  8  4]]
# Final Score:  856
# Score: 856
# [[ 2  4  8  4]
#  [16  2 64  2]
#  [ 4  8 32  4]
#  [ 2 64 16  2]]
# Final Score:  3664
# Score: 3664
# [[  4 128   8   2]
#  [  2   4   2   4]
#  [ 16 128  16  64]
#  [  8   4 256   2]]
# Final Score:  952
# Score: 952
# [[16  2  8  2]
#  [ 4 32 16  4]
#  [ 2 64  8 64]
#  [ 8 16  2  4]]
# Final Score:  1360
# Score: 1360
# [[  8   2   8   2]
#  [  2 128  64   8]
#  [  4   8  32  16]
#  [  2  16   8   2]]
# Final Score:  2276
# Score: 2276
# [[ 16   2   8   2]
#  [  2   4 256  64]
#  [  8  16  32   2]
#  [  2   4   2   8]]
# Final Score:  3052
# Score: 3052
# [[  2   8 256   2]
#  [  4 128   2  32]
#  [ 16  64   8   2]
#  [  4  16   2   4]]
# Final Score:  1392
# Score: 1392
# [[  2  16 128   4]
#  [ 16   2   4  32]
#  [  2  32  64   4]
#  [  4   2   4   2]]
# Final Score:  2248
# Score: 2248
# [[  4  16   2  64]
#  [ 16 256   4   2]
#  [  4   2  16   8]
#  [  2  16   2   4]]
# Final Score:  2900
# Score: 2900
# [[  2   4  16   2]
#  [  8   2  64   4]
#  [  2   8 256  16]
#  [  4 128   2   4]]
# Final Score:  1284
# Score: 1284
# [[  4   2 128   2]
#  [  2  32   2   4]
#  [  4  16   8  16]
#  [  2  64   4   2]]
# Final Score:  656
# Score: 656
# [[ 4 16  4  2]
#  [16  8 64  8]
#  [ 4 32 16  4]
#  [ 2 16  8  2]]
# Final Score:  1248
# Score: 1248
# [[  2   4  16   4]
#  [  4  16   4   8]
#  [  8 128  16   2]
#  [  4  64   8   4]]
# Final Score:  860
# Score: 860
# [[ 2  4 64  4]
#  [ 8 32 16  2]
#  [ 4 16 64  4]
#  [ 2  4  8  2]]
# Final Score:  1408
# Score: 1408
# [[  2   4  64   4]
#  [  8  32   8  16]
#  [  2   8   2   4]
#  [128   4  32   2]]
# Final Score:  1156
# Score: 1156
# [[  2   4   8   2]
#  [ 64  16   2   4]
#  [  2   8 128   8]
#  [  8   2   4   2]]
# Final Score:  1616
# Score: 1616
# [[  2   4  16   2]
#  [  4  64 128   8]
#  [  8  32  16   4]
#  [  4  64   4   2]]
# Final Score:  2828
# Score: 2828
# [[  4   8  16   2]
#  [  2   4 256   4]
#  [ 16  32 128  16]
#  [  4  16   4   2]]
# Final Score:  2328
# Score: 2328
# [[  2  16   4   2]
#  [ 16   4  32  64]
#  [  4 256  16   2]
#  [  2   4   2   4]]
# Final Score:  1480
# Score: 1480
# [[  4   2  32   4]
#  [  2  64   4   2]
#  [  4 128  32  16]
#  [  2  32   8   2]]
# Final Score:  2360
# Score: 2360
# [[  2   4   2   8]
#  [  8  16 256   2]
#  [  4  32  16   8]
#  [  8  16  64   4]]
# Final Score:  2612
# Score: 2612
# [[  2   4  16   2]
#  [ 64  32  64   8]
#  [  2   4 256   2]
#  [  4  16   8   4]]
# Final Score:  2196
# Score: 2196
# [[  4   8   4   2]
#  [ 16  32  16  32]
#  [  4  16 256   8]
#  [  2   8   4   2]]
# Final Score:  2984
# Score: 2984
# [[  4  16   2   8]
#  [  8   4 256   2]
#  [ 16  64 128   4]
#  [  2  16   8   2]]
# Final Score:  1412
# Score: 1412
# [[  2  16   2   8]
#  [  4 128   4   2]
#  [ 32   8  64   8]
#  [  8   2  32   2]]
# Final Score:  2460
# Score: 2460
# [[  2  16   8  64]
#  [  4  64   4   2]
#  [  8   4 256   4]
#  [  4   2   8   2]]
# Final Score:  1344
# Score: 1344
# [[ 16   2  64   2]
#  [  8  16   2   4]
#  [128   4   8   2]
#  [  2  16  32   4]]
# Final Score:  2864
# Score: 2864
# [[  8   4 128   2]
#  [  2  16 256   4]
#  [  8  32  16  32]
#  [  4   2   8   4]]
# Final Score:  928
# Score: 928
# [[ 4  8 64  8]
#  [16  4 16  2]
#  [32 16 64  4]
#  [ 2  8  4  2]]
# Final Score:  1280
# Score: 1280
# [[  4   2   4   2]
#  [  8   4  64   4]
#  [  2 128   2  16]
#  [  8  16   4  32]]
# Final Score:  1960
# Score: 1960
# [[  4   2 128   4]
#  [  8  16   4 128]
#  [  2   4  64   4]
#  [  8  16   8   2]]
# Final Score:  932
# Score: 932
# [[  8   2   8   2]
#  [  2   4  16   4]
#  [ 16   2 128   8]
#  [  2   8   2   4]]
# Final Score:  1344
# Score: 1344
# [[  2   4   2   4]
#  [  4  32  16   2]
#  [  2  16 128  64]
#  [  4   2  16   2]]
# Final Score:  2948
# Score: 2948
# [[  2  32   2   4]
#  [256  16   8  32]
#  [  2  32 128   4]
#  [  4   2  16   2]]
# Final Score:  1312
# Score: 1312
# [[ 16   4   2   8]
#  [  4  64  32   2]
#  [  2   8  16   4]
#  [  4 128   8   2]]
# Final Score:  1172
# Score: 1172
# [[  4   2   4   2]
#  [  2  16  32   4]
#  [ 32 128  16   8]
#  [  2  16   8   4]]
# Final Score:  588
# Score: 588
# [[ 2  4  8  4]
#  [ 8 64 16  2]
#  [16 32  2  4]
#  [ 2  8  4  2]]
# Final Score:  2456
# Score: 2456
# [[  4  32   4   2]
#  [ 16  64  16   8]
#  [  8  32 256  16]
#  [  2   8   4   2]]
# Final Score:  1996
# Score: 1996
# [[  4  16   8   2]
#  [128   4  32   4]
#  [  8 128   4  64]
#  [  2   4   8   4]]
# Final Score:  2792
# Score: 2792
# [[  2   8   2   4]
#  [  8  32 128   8]
#  [  4 256   8   2]
#  [ 16   8   4  16]]
# Final Score:  1368
# Score: 1368
# [[  8  32   2   4]
#  [ 16 128   4   8]
#  [  4  64  16   4]
#  [  2  16   8   2]]
# Final Score:  2944
# Score: 2944
# [[  4  16   4   2]
#  [  2  32 256  32]
#  [  4   8  32   4]
#  [128   2   8   2]]
# Final Score:  2000
# Score: 2000
# [[  2   8 128   2]
#  [  8  16   2   4]
#  [ 16 128   8  16]
#  [  4  64   2   4]]
# Final Score:  2728
# Score: 2728
# [[  2   4   8   2]
#  [  4  16 256   4]
#  [  8 128  32   8]
#  [  4   8   2   4]]
# Final Score:  2392
# Score: 2392
# [[  2   4   8   4]
#  [  4  64  16   2]
#  [ 32 256  32   4]
#  [  2  16   4   2]]
# Final Score:  2904
# Score: 2904
# [[  2   4  32   4]
#  [ 16 128   4   8]
#  [  2  16 256  16]
#  [  4   2  32   4]]
# Final Score:  792
# Score: 792
# [[ 2  8  2  4]
#  [32  2  8 64]
#  [ 4 64  4  2]
#  [ 2  4  2  8]]
# Final Score:  744
# Score: 744
# [[ 2  4 16  2]
#  [ 8 32 64  4]
#  [16  8 16  8]
#  [ 2  4 32  2]]
# Final Score:  1188
# Score: 1188
# [[  2   8  16   2]
#  [ 16 128   2   4]
#  [  4  32  16  32]
#  [  2   8   2   8]]
# Final Score:  2372
# Score: 2372
# [[  4   2  16   2]
#  [ 32   4   2   4]
#  [  4   2  16 256]
#  [  2   4  64  32]]
# Final Score:  1704
# Score: 1704
# [[  2   4 128   2]
#  [ 16   8   2   8]
#  [  8 128   4  16]
#  [  2   4  16   2]]
# Final Score:  936
# Score: 936
# [[ 2  8  2  4]
#  [ 4 32 16 64]
#  [ 2 64  4  2]
#  [ 8  2 32  4]]
# Final Score:  2592
# Score: 2592
# [[  4   8   4  32]
#  [  2 256   8   2]
#  [ 16  64   2   8]
#  [  4   2  64   2]]
# Final Score:  2768
# Score: 2768
# [[  4   2   4   2]
#  [  8 256 128  16]
#  [  4   8  32   2]
#  [  2  16   4   8]]
# Final Score:  1312
# Score: 1312
# [[  2   4   2   4]
#  [  8  16  64   2]
#  [  2  32 128   8]
#  [ 16   2  16   2]]
# Final Score:  1068
# Score: 1068
# [[  2   4   8   4]
#  [ 16   8  16   2]
#  [  8  32   8   4]
#  [  2  16 128   2]]
# Final Score:  1488
# Score: 1488
# [[  2   8   2   4]
#  [ 16  32  16   8]
#  [  2  64 128  16]
#  [ 32   2   8   2]]
# Final Score:  1488
# Score: 1488
# [[  2   4   2   8]
#  [ 32 128  32   2]
#  [  8  32  64   8]
#  [  2   4   8   4]]
# Final Score:  1436
# Score: 1436
# [[  8  32   4   2]
#  [ 16 128  16   4]
#  [  4  32  64   2]
#  [  2   8   2   8]]
# Final Score:  1492
# Score: 1492
# [[  4   8   4   2]
#  [  8   4  64   4]
#  [ 16   8 128  16]
#  [  4  64   8   4]]
# Final Score:  1440
# Score: 1440
# [[  2   4   8   4]
#  [  8  32   4   2]
#  [  2  16 128  16]
#  [ 32   4  64   8]]
# Final Score:  1172
# Score: 1172
# [[  2   4  16   8]
#  [  8  32   4  32]
#  [  2 128  16   4]
#  [  4  16   8   2]]
# Final Score:  1316
# Score: 1316
# [[  8   2   8   2]
#  [  2  32   2   4]
#  [ 16  64 128  16]
#  [  4   2   8   2]]
# Final Score:  1364
# Score: 1364
# [[  8  16   8   2]
#  [  4   8  32   4]
#  [ 16 128   4  16]
#  [  2  64   8   4]]
# Final Score:  5012
# Score: 5012
# [[  4   2   4  16]
#  [  2   4  32   8]
#  [  8  16 128   2]
#  [  2 512   8   4]]
# Final Score:  1080
# Score: 1080
# [[  2   4  32   2]
#  [  4 128   2   8]
#  [  2   4  32   4]
#  [ 16   2   8   2]]
# Final Score:  2416
# Score: 2416
# [[  2  16   2   8]
#  [  4  64  16   4]
#  [ 16  32 256  16]
#  [  4   8   4   2]]
# Final Score:  2436
# Score: 2436
# [[  2   8   4   2]
#  [  4  32  16   4]
#  [  2 256  32  16]
#  [  8  64   4   2]]
# Final Score:  1640
# Score: 1640
# [[  2  16   8   2]
#  [  8  64  16   4]
#  [  4  16 128  64]
#  [  2  32   4   2]]
# Final Score:  784
# Score: 784
# [[ 4 64  4  2]
#  [ 8  4  2 16]
#  [ 4 16  8  4]
#  [ 2  8 64  2]]
# Final Score:  2160
# Score: 2160
# [[  4   2   8   2]
#  [  2 256   2   4]
#  [  8  64   8  16]
#  [  4   8   4   2]]
# Final Score:  1704
# Score: 1704
# [[  2  32   4   2]
#  [  4   8  64   8]
#  [128   4  32   4]
#  [  4  16   4  64]]
# Final Score:  2420
# Score: 2420
# [[  2  16   2   4]
#  [  4 256  32   2]
#  [ 32   4   8  64]
#  [  4  16   4   2]]
# Final Score:  2364
# Score: 2364
# [[  8  16   2   4]
#  [  2  32  16 256]
#  [  8  16  64   4]
#  [  2   8   4   2]]
# Final Score:  1508
# Score: 1508
# [[  2   8  32   4]
#  [  4  64 128   2]
#  [ 32   8  16   8]
#  [  8   2  32   2]]
# Final Score:  2876
# Score: 2876
# [[  8   4 256   2]
#  [ 32   2  16   4]
#  [  4 128   8  32]
#  [  2   8  16   4]]
# Final Score:  1656
# Score: 1656
# [[  2   4  16   8]
#  [  8  32  64   2]
#  [ 64 128  16   8]
#  [  2   4   8   4]]
# Final Score:  1656
# Score: 1656
# [[  2   4   8   4]
#  [  8  32  64  16]
#  [ 16  64 128   4]
#  [  4   2  16   2]]
# Final Score:  1644
# Score: 1644
# [[  4   8  64   4]
#  [ 32   4 128   2]
#  [  4  16   2   4]
#  [ 64   2  32   2]]
# Final Score:  1364
# Score: 1364
# [[  2   8  16   2]
#  [  4 128  32   4]
#  [  2  16  64  16]
#  [  8   4   8   4]]
# Final Score:  1016
# Score: 1016
# [[  4 128   2   4]
#  [  2  16   8  16]
#  [  8   4  32   8]
#  [  4   2   4   2]]
# Final Score:  2456
# Score: 2456
# [[  2   8   2   4]
#  [ 16  32 256   2]
#  [  8   2  16   8]
#  [  2  64  32   4]]
# Final Score:  640
# Score: 640
# [[ 2  4  2  8]
#  [ 4 16  4  2]
#  [32 64 32  4]
#  [ 8  4  8  2]]
# Final Score:  1804
# Score: 1804
# [[  4  16   8   2]
#  [ 64   4 128   4]
#  [  4   2  64  16]
#  [ 64   8   2   8]]
# Final Score:  3628
# Score: 3628
# [[  8 128   8   2]
#  [  2   4   2   4]
#  [ 64 256  16   2]
#  [  2 128   2   4]]
# Final Score:  1908
# Score: 1908
# [[  4   2   8   4]
#  [128  64   4 128]
#  [  8   4   8   4]
#  [  2  16   4   2]]
# Final Score:  2348
# Score: 2348
# [[  4  16   2   8]
#  [ 16   2  32 256]
#  [  4  64   4   2]
#  [  2  16   8   4]]
# Final Score:  2036
# Score: 2036
# [[  4   2   4  64]
#  [ 32   4  16   4]
#  [128   2   8 128]
#  [  2   4  16   4]]
# Final Score:  1432
# Score: 1432
# [[  8   2   4   8]
#  [  2  32  16   2]
#  [  8  64 128   8]
#  [  2   4  32   2]]
# Final Score:  1284
# Score: 1284
# [[  2   4 128   2]
#  [  4   2  32   8]
#  [  8  64   8  16]
#  [  4   2   4   2]]
# Final Score:  2316
# Score: 2316
# [[  2   8  32   4]
#  [  4  64  16   2]
#  [  8   4 256   4]
#  [  4   2  16   2]]
# Final Score:  1332
# Score: 1332
# [[  2   8   4   2]
#  [ 32  16  64  16]
#  [  4 128   2   4]
#  [  2   4  16   2]]
# Final Score:  3064
# Score: 3064
# [[ 16   4   8   2]
#  [  2 128 256   4]
#  [  8  32   4  16]
#  [  4  64   2   4]]
# Final Score:  1436
# Score: 1436
# [[  2   4  16   2]
#  [  8  32 128  64]
#  [ 16   8  16   4]
#  [  2   4   8  16]]
# Final Score:  2996
# Score: 2996
# [[  4 256   8   4]
#  [  2   8  32   8]
#  [  8   4  64   4]
#  [  2 128   4   2]]
# Final Score:  1348
# Score: 1348
# [[  4  16   8   2]
#  [  2  32  64   8]
#  [  8 128   2   4]
#  [  4  16   4   8]]
# Final Score:  1384
# Score: 1384
# [[  4   8   4   2]
#  [ 16  32  64   8]
#  [  2 128  16   2]
#  [ 16   4   2   8]]
# Final Score:  3096
# Score: 3096
# [[  2   4  16   4]
#  [128 256  64  16]
#  [  8   4  32   4]
#  [  4  16   8   2]]
# Final Score:  1356
# Score: 1356
# [[  2   4   2   8]
#  [128  16  32   2]
#  [  2   8  64   4]
#  [ 16   4   2  16]]
# Final Score:  1624
# Score: 1624
# [[  4  64   4   2]
#  [  2   8  32   8]
#  [  8  16 128  16]
#  [  2   4  64   2]]
# Final Score:  1928
# Score: 1928
# [[  2   8   2   8]
#  [  4   2  16 128]
#  [  2 128  64   4]
#  [  4   8  16   2]]
# Final Score:  1260
# Score: 1260
# [[  2   4   8   4]
#  [  8 128   4   8]
#  [  4  64  32   4]
#  [  2   8   4   2]]
# Final Score:  2752
# Score: 2752
# [[  4   8   4   2]
#  [  8   4   8  16]
#  [  4  32 128   4]
#  [  2  16 256   2]]
# Final Score:  1216
# Score: 1216
# [[  2   8  32   2]
#  [  4  32   4   8]
#  [  8  16 128   2]
#  [  4  32   2   4]]
# Final Score:  2368
# Score: 2368
# [[  8  64   8   2]
#  [ 16   8  16   4]
#  [  4 256  32   8]
#  [  2  16   2   4]]
# Final Score:  1400
# Score: 1400
# [[  4   8  32   2]
#  [  8  64   2   4]
#  [  4   2 128  32]
#  [  2  16   4   2]]
# Final Score:  1364
# Score: 1364
# [[  4  32   4   2]
#  [  8 128   8   4]
#  [  2  16  64   2]
#  [ 16   8   2  16]]
# Final Score:  3048
# Score: 3048
# [[  2   8   4   2]
#  [ 64 128   8   4]
#  [  8 256  16  32]
#  [ 16   2   8   2]]
# Final Score:  1068
# Score: 1068
# [[  2  32   8   2]
#  [  8   4 128   4]
#  [  4  32  16   2]
#  [  2   4   2   8]]
# Final Score:  3120
# Score: 3120
# [[  2 256   8   2]
#  [ 32   8  64 128]
#  [  4  16   8   2]
#  [  2   8   4  32]]
# Final Score:  1364
# Score: 1364
# [[  2   8   4   2]
#  [  4  32 128   8]
#  [ 16  64   8   4]
#  [  4  16   2  16]]
# Final Score:  1568
# Score: 1568
# [[  2   4   8   2]
#  [ 64   2  64   4]
#  [  4  16 128  32]
#  [  2   8   4   2]]
# Final Score:  2092
# Score: 2092
# [[  4   8   4   2]
#  [ 16 256  16   4]
#  [ 32  16   4  16]
#  [  2   4   8   4]]
# Final Score:  1500
# Score: 1500
# [[  2 128   2   4]
#  [  8  64   4  16]
#  [  2   8  64   8]
#  [  4   2  16   2]]
# Final Score:  600
# Score: 600
# [[64  2  8  2]
#  [ 4  8 32  4]
#  [ 8 16  4 16]
#  [ 2  4  8  4]]
# Final Score:  1352
# Score: 1352
# [[  2   4  16   2]
#  [  4 128  32   4]
#  [ 16   4  64   8]
#  [  4   2  16   4]]
# Final Score:  1328
# Score: 1328
# [[ 16   2   4   8]
#  [  2 128   2   4]
#  [ 16   8  16  64]
#  [  4   2  32   2]]
# Final Score:  1736
# Score: 1736
# [[  8   4   8   2]
#  [128  16 128   8]
#  [  4  32   8   2]
#  [  2   8   2   4]]
# Final Score:  1324
# Score: 1324
# [[  2   4 128   2]
#  [ 16  32   2   4]
#  [  4  64   4   8]
#  [  2  16   8   2]]
# Final Score:  2980
# Score: 2980
# [[  2   4   8   2]
#  [ 16 256  16   4]
#  [  2   4  64  16]
#  [  8 128   4   2]]
# Final Score:  2600
# Score: 2600
# [[  4   8  32   2]
#  [  2  16 256   4]
#  [  8  64  32  16]
#  [  4  32  16   2]]
# Final Score:  844
# Score: 844
# [[ 2  4  2  4]
#  [64 32  8  2]
#  [ 4  8  4 16]
#  [ 2 64  8  2]]
# Final Score:  1124
# Score: 1124
# [[  2  16  32   2]
#  [  4   2 128   4]
#  [ 32   4  16   2]
#  [  2   8   4   8]]
# Final Score:  984
# Score: 984
# [[  4   2   4   8]
#  [  8  16 128   4]
#  [  4  32   2   8]
#  [  2   8   4   2]]
# Final Score:  1280
# Score: 1280
# [[  2   4  16   2]
#  [ 16  64   4   8]
#  [  2  16 128  16]
#  [  4   8   4   2]]
# Final Score:  2800
# Score: 2800
# [[  2   4   2   4]
#  [  8  16 256  16]
#  [  4 128   4  32]
#  [  2  16   2   4]]
# Final Score:  1496
# Score: 1496
# [[  2  32   8   2]
#  [ 32  64  32   4]
#  [  4 128   4   8]
#  [  8   2   8   4]]
# Final Score:  3176
# Score: 3176
# [[  2   4 128   4]
#  [256  16   8  32]
#  [  4   8   2  16]
#  [  2  32  64   2]]
# Final Score:  2196
# Score: 2196
# [[  8   2  16   2]
#  [  2 256   8  64]
#  [  8  16   4   2]
#  [  2   4   2   8]]
# Final Score:  668
# Score: 668
# [[ 2  4  8  2]
#  [ 8 32  4 32]
#  [ 2  8 64  8]
#  [ 4  2 16  2]]
# Final Score:  2412
# Score: 2412
# [[  8   2  32   2]
#  [ 16   8  64   4]
#  [  8   4 256   8]
#  [  2  32   2   4]]
# Final Score:  1644
# Score: 1644
# [[  4  16   4   2]
#  [ 16   4  64   8]
#  [  4 128  32   4]
#  [  2  64   4   8]]
# Final Score:  1112
# Score: 1112
# [[  8   2  32   2]
#  [ 16 128   2   8]
#  [  4   8   4  16]
#  [  2   4  32   4]]
# Final Score:  1420
# Score: 1420
# [[  2   4 128   4]
#  [ 16  32   4  16]
#  [  4  64   2   4]
#  [  2   8  32   2]]
# Final Score:  2244
# Score: 2244
# [[  2   4  16   2]
#  [  8  64   8   4]
#  [  4 256  16   8]
#  [  2  16   4   2]]
# Final Score:  1552
# Score: 1552
# [[  2   4  32   4]
#  [ 64  32 128   8]
#  [  4  16  32  16]
#  [  8   4   2   4]]
# Final Score:  1456
# Score: 1456
# [[  2   8  32   4]
#  [  4  64   8   2]
#  [  2   4  16  32]
#  [128  16   4   2]]
# Final Score:  1408
# Score: 1408
# [[  4   2  32   2]
#  [  2   8 128   8]
#  [ 64  32  16   4]
#  [  4  16   4   2]]
# Final Score:  1608
# Score: 1608
# [[ 32   4   2   4]
#  [  8  16   8   2]
#  [  4 128  64   8]
#  [  2  64   8   4]]
# Final Score:  5160
# Score: 5160
# [[  4  16   2   8]
#  [512 128   8   2]
#  [  8   4  64   8]
#  [  2   8   4   2]]
# Final Score:  1416
# Score: 1416
# [[  2   4   8   2]
#  [128  64  32   4]
#  [  4  32   8   2]
#  [  2   4  16   4]]
# Final Score:  520
# Score: 520
# [[ 4  2  8  2]
#  [ 2  8  4 16]
#  [ 4 64  8  4]
#  [ 2 32  4  2]]
# Final Score:  1472
# Score: 1472
# [[  2   4  16   2]
#  [ 16  64  32   4]
#  [  4  16   2   8]
#  [ 32   2 128   4]]
# Final Score:  1428
# Score: 1428
# [[ 32   2   4   2]
#  [  2   4  64  16]
#  [ 32 128   8   2]
#  [  2   8   2  16]]
# Final Score:  1308
# Score: 1308
# [[  2   4 128   2]
#  [  8  32   8  16]
#  [  2  64   4   2]
#  [  4   8  16   4]]
# Final Score:  2948
# Score: 2948
# [[256   2   4   2]
#  [  8   4   8   4]
#  [  2 128  16   8]
#  [ 16  64   4   2]]
# Final Score:  1628
# Score: 1628
# [[  2  32  64   2]
#  [  4   2  16   4]
#  [ 16  64 128   8]
#  [  2  16   4   2]]
# Final Score:  988
# Score: 988
# [[  4   2   4   2]
#  [  2   8 128   8]
#  [  4  32   2  16]
#  [  2   8   4   2]]
# Final Score:  3116
# Score: 3116
# [[ 64   4   8   2]
#  [  4  32   2   4]
#  [  2 128 256   8]
#  [  4   8   2  32]]
# Final Score:  760
# Score: 760
# [[ 2  4 16  2]
#  [16 32  2  4]
#  [ 4 64 16  8]
#  [ 2 16 32  4]]
# Final Score:  1124
# Score: 1124
# [[  2  32   2   4]
#  [ 16   2  32   2]
#  [  4  16 128   4]
#  [  2   8   2   8]]
# Final Score:  2980
# Score: 2980
# [[  2  16   8   2]
#  [  4  32   2   4]
#  [  2   8   4  64]
#  [256   2 128   2]]
# Final Score:  2396
# Score: 2396
# [[  4  16   4   2]
#  [ 16  32  16   8]
#  [  8   4 256  64]
#  [  2  16   4   2]]
# Final Score:  1668
# Score: 1668
# [[  2  64   4   2]
#  [  4  32  16   8]
#  [  8  16 128  64]
#  [  2   4  16   4]]
# Final Score:  2564
# Score: 2564
# [[  4   8   4   2]
#  [  2  64  32   8]
#  [  4   8  64 256]
#  [  2   4  16   2]]
# Final Score:  1348
# Score: 1348
# [[  2   8  16   2]
#  [ 16  32   4  16]
#  [  8  64   8   4]
#  [  4   2 128   2]]
# Final Score:  2628
# Score: 2628
# [[  2  16   4   2]
#  [256   2 128   4]
#  [ 16   8  16   8]
#  [  4   2   4   2]]
# Final Score:  1248
# Score: 1248
# [[  2   8   4   2]
#  [ 16   2 128  16]
#  [  8  64   8   2]
#  [  2  16   2   4]]
# Final Score:  532
# Score: 532
# [[ 2  4  8  4]
#  [ 8 16 32  2]
#  [ 4 64  2  4]
#  [ 2  4  8  2]]
# Final Score:  1456
# Score: 1456
# [[  4   2  32   8]
#  [ 16 128  64   2]
#  [  2  16   8   4]
#  [  4  32   4   2]]
# Final Score:  1384
# Score: 1384
# [[  8   2  16   2]
#  [  2  16  64   8]
#  [  4 128  16   2]
#  [  2  16  32   4]]
# Final Score:  2652
# Score: 2652
# [[  4   8   4   2]
#  [ 16   4  16   8]
#  [  2   8 128 256]
#  [  8   2   4   2]]
# Final Score:  3352
# Score: 3352
# [[  8   2   8   2]
#  [  2  16  64 128]
#  [ 64   8  32   4]
#  [  4   2 256   8]]
# Final Score:  1460
# Score: 1460
# [[  4  16   4   2]
#  [  8   4   8  16]
#  [  4 128  32  64]
#  [  2  32  16   4]]
# Final Score:  1596
# Score: 1596
# [[  2   8   4   2]
#  [  4  32  16   8]
#  [ 64   2  64 128]
#  [  4   8   4   2]]
# Final Score:  4712
# Score: 4712
# [[  2   8  32   2]
#  [  4  16   2 256]
#  [ 32 256   8  32]
#  [  2   4 128   2]]
# Final Score:  576
# Score: 576
# [[ 4  8 16  2]
#  [ 8 32  4  8]
#  [ 4  8 64  2]
#  [ 2 16  8  4]]
# Final Score:  560
# Score: 560
# [[ 2  8  4  2]
#  [ 8  2  8  4]
#  [16 32 64  8]
#  [ 2  4  8  4]]
# Final Score:  2412
# Score: 2412
# [[ 32   4   8  64]
#  [  2  16  32   2]
#  [ 16   2 256   8]
#  [  2   4   2   4]]
# Final Score:  1356
# Score: 1356
# [[  2   4   8   2]
#  [ 16  64 128  16]
#  [  4   8   2   4]
#  [  8  32  16   2]]
# Final Score:  1396
# Score: 1396
# [[  4   2   4   2]
#  [  2   4  64  32]
#  [ 16  32 128   2]
#  [  2   8   4   8]]
# Final Score:  2424
# Score: 2424
# [[  4   8   4   8]
#  [  8  32 256   2]
#  [ 16  64  32   8]
#  [  2  16   4   2]]
# Final Score:  2888
# Score: 2888
# [[  2 128   8   2]
#  [  8  32   2  16]
#  [ 16   2 256   2]
#  [  8  32   8   4]]
# Final Score:  1184
# Score: 1184
# [[  2   4   8   4]
#  [  4  16   4   2]
#  [  2 128  64   8]
#  [ 16   4   8   4]]
# Final Score:  748
# Score: 748
# [[ 2 16  8  2]
#  [32  4 16  4]
#  [ 4  8 32  8]
#  [ 2 64 16  2]]
# Final Score:  3092
# Score: 3092
# [[ 16 128   4   2]
#  [  4  64 256  16]
#  [  8  16  32   2]
#  [  2   4   2   8]]
# Final Score:  4696
# Score: 4696
# [[  2   4  16   2]
#  [ 32  16 512   8]
#  [  2   4  64  32]
#  [  4   8   4   2]]
# Final Score:  1540
# Score: 1540
# [[ 16   2   8   4]
#  [  4  16 128  16]
#  [ 64   4   2   4]
#  [  8   2  64   2]]
# Final Score:  620
# Score: 620
# [[ 2  8  2  4]
#  [ 4 64 32 16]
#  [ 2 32  2  4]
#  [ 4  2  8  2]]
# Final Score:  2712
# Score: 2712
# [[  2   8   4   2]
#  [  4   2  32   8]
#  [  2 128 256   2]
#  [  8  16   2   4]]
# Final Score:  2884
# Score: 2884
# [[  2   4   8   2]
#  [  8 128   2   4]
#  [  2   4   8  64]
#  [  8 256   2   8]]
# Final Score:  1360
# Score: 1360
# [[  2   4  16   2]
#  [ 16   8   4  32]
#  [  2 128  16   8]
#  [  4   8  64   2]]
# Final Score:  2336
# Score: 2336
# [[  2   4   8   2]
#  [  8  64  16 256]
#  [  4  16  32   8]
#  [  2   8   4   2]]
# Final Score:  1084
# Score: 1084
# [[  2  16   4   2]
#  [ 16 128  16   4]
#  [  8   4  32   2]
#  [  4  16   2   8]]
# Final Score:  696
# Score: 696
# [[ 2  8 32  4]
#  [ 4  2  8  2]
#  [16 32 64  8]
#  [ 4 16  2  4]]
# Final Score:  436
# Score: 436
# [[ 2  4 16  2]
#  [16 32  8  4]
#  [ 2  4 16  8]
#  [32  2  8  2]]
# Final Score:  956
# Score: 956
# [[32  2 64  4]
#  [ 2  4 16  8]
#  [32  2  4 64]
#  [ 2  4  8  4]]
# Final Score:  3016
# Score: 3016
# [[  2   4  16   4]
#  [ 16   2 128  16]
#  [  4 256   4  64]
#  [  2   8  16   2]]
# Final Score:  2180
# Score: 2180
# [[  8   2   8   2]
#  [  4  32  16   8]
#  [ 16 256   2  16]
#  [  2   4  32   2]]
# Final Score:  1632
# Score: 1632
# [[  4   2  16   2]
#  [  8  16 128   4]
#  [  4  64   8  32]
#  [  2   8   4  64]]
# Final Score:  1444
# Score: 1444
# [[  2   8 128   4]
#  [  4  64   8  32]
#  [ 16   2  16   2]
#  [  4  32   2   8]]
# Final Score:  1392
# Score: 1392
# [[  4   2   8   2]
#  [  8  16   2  16]
#  [ 64  32 128   8]
#  [  8  16   4   2]]
# Final Score:  1280
# Score: 1280
# [[  2   4   8   2]
#  [128  64   2   4]
#  [  2   4  32   8]
#  [  8   2  16   2]]
# Final Score:  1256
# Score: 1256
# [[  2   4  16   2]
#  [  4   8 128   4]
#  [  8  16   8  16]
#  [  2  64   4   2]]
# Final Score:  908
# Score: 908
# [[ 4  8  2  8]
#  [ 8 16 64  4]
#  [32  8 16 64]
#  [ 2  4  8  2]]
# Final Score:  664
# Score: 664
# [[ 2  8  4  2]
#  [ 4 32  2  4]
#  [ 2  4 16 64]
#  [16  2 32  2]]
# Final Score:  1500
# Score: 1500
# [[  2   4   8   2]
#  [ 16  32 128   8]
#  [  8  64  32  16]
#  [  2  16   4   2]]
# Final Score:  1472
# Score: 1472
# [[  2   8   4   2]
#  [ 16  32  16   4]
#  [  8  64 128  16]
#  [  4  32   4   2]]
# Final Score:  2464
# Score: 2464
# [[  4  32   4   2]
#  [  8  64   8   4]
#  [256   4  32  16]
#  [  2  16   4   8]]
# Final Score:  2056
# Score: 2056
# [[  4  16   4   2]
#  [ 16   4  16   4]
#  [  4  32   8 256]
#  [  2   8   2   4]]
# Final Score:  1324
# Score: 1324
# [[  4   8   4   8]
#  [ 32  16 128   2]
#  [  4   2  64  16]
#  [  2   4   8   4]]
# Final Score:  2988
# Score: 2988
# [[  2   4   8   4]
#  [ 32   2  16   2]
#  [  8  64 256   4]
#  [  2 128   4   2]]
# Final Score:  3144
# Score: 3144
# [[ 32   2 128   2]
#  [  2  16   8   4]
#  [  4 256  64  32]
#  [  2   4   8   4]]
# Final Score:  1144
# Score: 1144
# [[ 2 16  8  2]
#  [16  4 64  4]
#  [ 4 64 16  8]
#  [ 2 16 64  4]]
# Final Score:  3384
# Score: 3384
# [[  4   8 128   4]
#  [ 16 256   8   2]
#  [  4   2   4 128]
#  [  2  16   8   2]]
# Final Score:  2836
# Score: 2836
# [[  4   2   8   2]
#  [  2  32  16 256]
#  [  4   8 128   4]
#  [  2   4  32  16]]
# Final Score:  5372
# Score: 5372
# [[  2   4 128   4]
#  [  8  32   4 512]
#  [ 16   4  32  64]
#  [  4   8   2   4]]
# Final Score:  2884
# Score: 2884
# [[  2  32   8   2]
#  [128   4  32   4]
#  [  4  32   2   8]
#  [  2 256   4   2]]
# Final Score:  2756
# Score: 2756
# [[  4   2   4   2]
#  [  8 256 128   4]
#  [  2  16   4   8]
#  [ 32   8   2  16]]
# Final Score:  1424
# Score: 1424
# [[  2   4   8   2]
#  [  8  32   4  16]
#  [  4  64 128   4]
#  [  8  32   4   2]]
# Final Score:  2892
# Score: 2892
# [[  2   8  16   2]
#  [  4 256   2   8]
#  [ 32   8  32 128]
#  [  8  16   8   4]]
# Final Score:  1320
# Score: 1320
# [[  8  16   4   2]
#  [  2  64   2   8]
#  [ 16 128   4   2]
#  [  2   4  32   4]]
# Final Score:  1452
# Score: 1452
# [[  4   8   4   2]
#  [  8 128  64   8]
#  [ 32  16   4  16]
#  [  4  32   8   4]]
# Final Score:  2736
# Score: 2736
# [[  4   8 256   2]
#  [  2  16   4  16]
#  [  8 128   8   4]
#  [  4  16   2   8]]
# Final Score:  1460
# Score: 1460
# [[  2   8  16   2]
#  [  4  32 128   8]
#  [ 16  64   4   2]
#  [  2  32   2   8]]
# Final Score:  1612
# Score: 1612
# [[  4   2  16   2]
#  [  2  16   2   8]
#  [ 64 128  32   2]
#  [  4   2   4  64]]
# Final Score:  660
# Score: 660
# [[ 2 32  4  2]
#  [ 8  4 16  8]
#  [ 2  8 32  2]
#  [ 4  2 64  8]]
# Final Score:  2300
# Score: 2300
# [[  2   4  16   4]
#  [  8  32   8  16]
#  [ 32  16 256   8]
#  [  8   2  32   2]]
# Final Score:  688
# Score: 688
# [[ 4  2  8  4]
#  [ 8 16  4 32]
#  [16 32  2  4]
#  [ 2  4 64  2]]
# Final Score:  3176
# Score: 3176
# [[  4   2   4  32]
#  [ 16  32 256   8]
#  [  4 128  16  64]
#  [  2   8   4   2]]
# Final Score:  672
# Score: 672
# [[ 4 16  4  2]
#  [ 2  4  8 32]
#  [32 16 64  2]
#  [ 2  4  2  8]]
# Final Score:  1540
# Score: 1540
# [[  4   2   4   2]
#  [  2  64 128  32]
#  [  4   8  64   4]
#  [  2   4   8   2]]
# Final Score:  1748
# Score: 1748
# [[  4   8  32   2]
#  [  8   4 128  64]
#  [ 16  64  32   8]
#  [  2   8   4   2]]
# Final Score:  576
# Score: 576
# [[ 2 32  4  2]
#  [ 4 16 64 16]
#  [ 8  2  4  2]
#  [ 2  8  2  8]]
# Final Score:  3988
# Score: 3988
# [[  4   8 128   2]
#  [128   4  16  64]
#  [  4  64   4   8]
#  [  2 256   8   4]]
# Final Score:  1804
# Score: 1804
# [[  2   8  16   4]
#  [  4   2 128  16]
#  [128  16  32   8]
#  [  2   4   8   4]]
# Final Score:  1992
# Score: 1992
# [[  2  16   8   2]
#  [  8   4 256  16]
#  [  4  32   8   2]
#  [  2   4   2   4]]
# Final Score:  2956
# Score: 2956
# [[  8   2   4   2]
#  [  4 256   2 128]
#  [ 16  64  16   8]
#  [  2   8   2   4]]
# Final Score:  2364
# Score: 2364
# [[  4   8   4   2]
#  [  2  64   2  32]
#  [  4 256  32   4]
#  [  2   8   4   2]]
# Final Score:  2872
# Score: 2872
# [[  2   4  32   8]
#  [  4   2  16   4]
#  [ 16 256  32 128]
#  [  4   8   2   8]]
# Final Score:  2988
# Score: 2988
# [[  2   4  16   2]
#  [  8  32   8   4]
#  [  4   8 128  32]
#  [  2  32 256   4]]
# Final Score:  2644
# Score: 2644
# [[  4   8   4  16]
#  [ 64  16  64 256]
#  [  4  32  16   4]
#  [  2   8   4   2]]
# Final Score:  2360
# Score: 2360
# [[  2   4  32   2]
#  [ 64  16   4   8]
#  [ 16   8 256   2]
#  [  2   4   2  16]]
# Final Score:  1260
# Score: 1260
# [[  4   2  16   2]
#  [  2  32   2   4]
#  [ 64   4 128   8]
#  [  4   2   8   4]]
# Final Score:  1652
# Score: 1652
# [[  4   2   8   4]
#  [128   8  64  32]
#  [  8  64  32   8]
#  [  2   8   4   2]]
# Final Score:  2984
# Score: 2984
# [[  2   4  16   2]
#  [  4  64   2   8]
#  [ 16 128   8 256]
#  [  4  16   4   2]]
# Final Score:  1620
# Score: 1620
# [[  2   8 128   2]
#  [  4  16  64   4]
#  [  8   4  32   8]
#  [  4  16  64   4]]
# Final Score:  1300
# Score: 1300
# [[  2   8   4   2]
#  [  4 128   2   8]
#  [  8  64  16  32]
#  [  4  16   4   2]]
# Final Score:  1232
# Score: 1232
# [[  4  16   2  16]
#  [  2   8 128   2]
#  [  8   2  64   8]
#  [  2   4   2  16]]
# Final Score:  1472
# Score: 1472
# [[  4  16   2   8]
#  [  2  64   4   2]
#  [  4   8 128   8]
#  [  2  64   4   2]]
# Final Score:  696
# Score: 696
# [[ 2  4 16  2]
#  [ 8 32 64  4]
#  [16  2  4  8]
#  [ 2 32  2  4]]
# Final Score:  1364
# Score: 1364
# [[  4   2  16   2]
#  [ 16  64  32   4]
#  [  4 128   4   8]
#  [  2   8  16   2]]
# Final Score:  4716
# Score: 4716
# [[  2   4  16   2]
#  [ 32  64   4   8]
#  [  8 512   8  32]
#  [ 16   8   2   4]]
# Final Score:  3148
# Score: 3148
# [[  2  64   4   2]
#  [ 16  32  16 256]
#  [128   4  32   8]
#  [  4   8   4   2]]
# Final Score:  3028
# Score: 3028
# [[  8  64   2   4]
#  [  2   4   8 128]
#  [ 32   2   4  16]
#  [  2 256   8   4]]

# %%
x = np.arange(1, 101)
plt.plot(x, sorted(res[0])) # Sorting these so we can see a little of what's happening here
plt.plot(x, sorted(res[1]))
plt.plot(x, sorted(res[2]))
plt.legend(["Game Score", "Emptiness", "Monotonicity"])
plt.xlabel("Attempt #")
plt.ylabel("Final Game Score")

plt.show()
